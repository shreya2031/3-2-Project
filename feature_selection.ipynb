# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/3-2-Project/finalData.csv')

# %%
data.head()
# Out:
#    chroma_stft_min  chroma_stft_max  chroma_cqt_min  chroma_cqt_max  \
# 0         0.000465              1.0        0.015500             1.0
# 1         0.000995              1.0        0.055937             1.0
# 2         0.002606              1.0        0.045407             1.0
# 3         0.001447              1.0        0.041263             1.0
# 4         0.002157              1.0        0.040596             1.0
#
#    chroma_cens_min  chroma_cens_max  melspectogram_min  melspectogram_max  \
# 0         0.000000         0.896673       4.632946e-06         8115.67330
# 1         0.015298         0.711400       4.666356e-07          911.08636
# 2         0.000000         0.748225       1.753200e-06         4857.33900
# 3         0.000000         0.782758       3.110815e-07         3757.07840
# 4         0.001198         0.717803       5.209164e-06         4824.61400
#
#     mfcc_min   mfcc_max  ...  zero_crossing_rate_min  zero_crossing_rate_max  \
# ...

# %%
array = data.values
X = array[:,0:35]
Y = array[:,35]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/3-2-Project/finalData.csv')
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
array = data.values
X = array[:,0:35]
Y = array[:,35]

# Feature extraction
model = LogisticRegression()
rfe = RFE(model, 1)
fit = rfe.fit(X, Y)
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))
# Out:
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=1 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
import sklearn
sklearn.feature_selection.f_regression(X, Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1365870ab558> in <module>
#       1 import sklearn
# ----> 2 sklearn.feature_selection.f_regression(X, Y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in f_regression(X, y, center)
#     287     # need not center X
#     288     if center:
# --> 289         y = y - np.mean(y)
#     290         if issparse(X):
#     291             X_means = X.mean(axis=0).getA1()
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ...

# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
#Loading the dataset
x = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/Project/feature_extraction/ghazalFinal.csv',header=None)
df = pd.DataFrame(x.data,columns = x.feature_names)
df["class"] = x.target
X = df.drop("class",34)   #Feature Matrix
y = df["class"]          #Target Variable
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f96af7d16cfa> in <module>
#      15 x = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/Project/feature_extraction/ghazalFinal.csv',header=None)
#      16 #df = pd.DataFrame(x.data,columns = x.feature_names)
# ---> 17 df["class"] = x.target
#      18 X = df.drop("class",34)   #Feature Matrix
#      19 y = df["class"]          #Target Variable
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
# Load libraries
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
  
# Load iris data
#iris_dataset = load_iris()
data = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/Project/feature_extraction/ghazalFinal.csv')
array = data.values
X = array[:,0:33]
Y = array[:,33]
# Create features and target
#X = iris_dataset.data
#y = iris_dataset.target
  
# Convert to categorical data by converting data to integers
X = X.astype(float)
  
# Two features with highest chi-squared statistics are selected
chi2_features = SelectKBest(chi2, k = 2)
X_kbest_features = chi2_features.fit_transform(X, Y)
  
# Reduced features
print('Original feature number:', X.shape[1])
print('Reduced feature number:', X_kbest.shape[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-3c77960ecfd1> in <module>
#      19 # Two features with highest chi-squared statistics are selected
#      20 chi2_features = SelectKBest(chi2, k = 2)
# ---> 21 X_kbest_features = chi2_features.fit_transform(X, Y)
#      22
#      23 # Reduced features
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
# --> 693             return self.fit(X, y, **fit_params).transform(X)
#     694
#     695
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     351
#     352         self._check_params(X, y)
# --> 353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
# ...

# %%
data.values
# Out:
# array([[0.0012518167, 1.0, 0.028087497000000003, ..., 12.531638000000001,
#         3, 'Sab Qatl Ho Ke Tere_shortened.wav'],
#        [0.0012359938, 1.0, 0.049233038, ..., 16.32825, 3,
#         'Sabab Tayana Kuthali Sangu_shortened.wav'],
#        [0.00016414783, 1.0, 0.009047217, ..., 11.388083, 3,
#         'Sabhi Andaz E Husn Pyare Hain (pyar)_shortened.wav'],
#        ...,
#        [0.00032329565, 1.0, 0.015643203999999997, ..., 12.439926, 3,
#         'Ye Bhi Kya Shaam- E- Mulaqat Aayi (shaam e   1)_shortened.wav'],
#        [0.0020536033, 1.0, 0.03504121, ..., 11.40654, 3,
#         'Ye Din To Aata Hai (2)_shortened.wav'],
#        [0.00011920716000000001, 1.0, 0.026377982999999997, ...,
#         12.506283, 3, 'Ye Hasin Jawan Nazare_shortened.wav']],
#       dtype=object)

# %%
#Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)

#Import the required packages

#Import pandas to read csv import pandas

#Import numpy for array related operations import numpy

#Import sklearn's feature selection algorithm
import pandas as pd
from sklearn.feature_selection import SelectKBest,f_regression

#Import chi2 for performing chi square test from sklearn.feature_selection import chi2

#URL for loading the dataset



#Define the attribute names

#Create pandas data frame by loading the data from URL

dataframe = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/Project/feature_extraction/ghazalFinal.csv')

#Create array from data values

array = dataframe.values

#Split the data into input and target

X = array[:,0:34]

Y = array[:,34]

#We will select the features using chi square

test = SelectKBest(score_func=f_regression, k=4)

#Fit the function for ranking the features by score

fit = test.fit(X, Y)

#Summarize scores numpy.set_printoptions(precision=3) print(fit.scores_)

#Apply the transformation on to dataset

features = fit.transform(X)

#Summarize selected features print(features[0:5,:])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-48-93bdc312c9f7> in <module>
#      39 #Fit the function for ranking the features by score
#      40
# ---> 41 fit = test.fit(X, Y)
#      42
#      43 #Summarize scores numpy.set_printoptions(precision=3) print(fit.scores_)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     351
#     352         self._check_params(X, y)
# --> 353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
#     355             self.scores_, self.pvalues_ = score_func_ret
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
#Import the required packages

#Import pandas to read csv import pandas

#Import numpy for array related operations import numpy

#Import sklearn's PCA algorithm

from sklearn.decomposition import PCA

#URL for loading the dataset


dataframe = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/Project/feature_extraction/ghazalFinal.csv')

#Create array from data values

array = dataframe.values

#Split the data into input and target

X = array[:,0:33]

Y = array[:,33]

#Feature extraction

pca = PCA(n_components=3) 
fit = pca.fit(X)

#Summarize components

print("Explained Variance: %s") 

print(fit.components_)
# Out:
# Explained Variance: %s
# [[ 1.41549787e-07  0.00000000e+00 -1.95401936e-07  5.55111512e-17
#   -1.32608945e-09  2.13023397e-06 -9.37619816e-11 -1.22850454e-01
#    1.40975985e-04  5.15364094e-03  4.78253495e-07 -1.17479356e-05
#   -7.63166501e-03 -6.00873130e-01 -4.43011130e-02 -2.52094130e-01
#    8.24080390e-05  3.17033612e-04 -1.93069195e-08 -3.37413185e-05
#   -1.68792473e-02 -7.46973904e-01 -1.59783560e-06 -2.42547021e-04
#    8.39174196e-07  1.12752135e-06  7.42774398e-07 -4.90330794e-05
#   -7.02588325e-21  0.00000000e+00  1.37486447e-03 -1.84485463e-03
#    0.00000000e+00]
#  [-2.19054487e-07  1.11022302e-16 -8.92915359e-07 -2.22044605e-16
#   -2.37086188e-07  8.68163341e-06  8.54494664e-11  9.86498339e-01
#    1.32102167e-02  1.57589409e-03  5.37717992e-06  6.35050391e-05
#   -4.30410332e-02 -9.43392851e-02 -2.75225771e-02  5.23815217e-03
#   -1.58885547e-04 -4.27619280e-04 -2.40408055e-08 -4.69328113e-06
#   -8.97101601e-02 -8.40129864e-02  4.18121938e-05  4.10080218e-04
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(36,36))
cor = dataframe.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso

data = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/3-2-Project/finalData.csv')
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
feature_cols = ['chroma_stft_min', 'chroma_stft_max', 'chroma_cqt_min',
       'chroma_cqt_max', 'chroma_cens_min', 'chroma_cens_max',
       'melspectogram_min', 'melspectogram_max', 'mfcc_min', 'mfcc_max',
       'rms_min', 'rms_max', 'spectral_centroid_min', 'spectral_centroid_max',
       'spectral_bandwidth_min', 'spectral_bandwidth_max',
       'spectral_contrast_min', 'spectral_contrast_max',
       'spectral_flatness_min', 'spectral_flatness_max',
       'spectral_rolloff_min', 'spectral_rolloff_max', 'poly_features_min',
       'poly_features_max', 'tonnetz_min', 'tonnetz_max',
       'zero_crossing_rate_min', 'zero_crossing_rate_max', 'tempogram_min',
       'tempogram_max', 'delta_mfcc_min', 'delta_mfcc_max', 'mel_to_stft_min',
       'mel_to_stft_max']
target_var = ['class']
X = data[feature_cols] # Features
y = data[target_var] # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
pipeline = Pipeline([
                     ('scaler',StandardScaler()),
                     ('model',Lasso())
])
search = GridSearchCV(pipeline,
                      {'model__alpha':np.arange(0.1,10,0.1)},
                      cv = 5, scoring="neg_mean_squared_error",verbose=3
                      )
search.fit(X_train,y_train)
search.best_params_
coefficients = search.best_estimator_.named_steps['model'].coef_
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# [CV] model__alpha=0.1 ................................................
# [CV] ................... model__alpha=0.1, score=-1.440, total=   0.0s
# [CV] model__alpha=0.1 ................................................
# [CV] ................... model__alpha=0.1, score=-1.226, total=   0.0s
# [CV] model__alpha=0.1 ................................................
# [CV] ................... model__alpha=0.1, score=-1.465, total=   0.0s
# [CV] model__alpha=0.1 ................................................
# [CV] ................... model__alpha=0.1, score=-1.538, total=   0.0s
# [CV] model__alpha=0.1 ................................................
# [CV] ................... model__alpha=0.1, score=-1.374, total=   0.0s
# [CV] model__alpha=0.2 ................................................
# [CV] ................... model__alpha=0.2, score=-1.597, total=   0.0s
# ...

# %%
importance = np.abs(coefficients)
np.array(feature_cols)[importance > 0]
# Out:
# array(['chroma_cqt_min', 'chroma_cens_min', 'melspectogram_max',
#        'mfcc_max', 'rms_min', 'spectral_bandwidth_min',
#        'spectral_flatness_min', 'spectral_rolloff_min',
#        'spectral_rolloff_max', 'poly_features_min', 'poly_features_max',
#        'tonnetz_max', 'zero_crossing_rate_max', 'delta_mfcc_min',
#        'mel_to_stft_max'], dtype='<U22')

# %%
data = pd.read_csv('C:/Users/Sahithi Venkatesan/Desktop/3-2-Project/finalData.csv')
feature_cols = ['chroma_stft_min', 'chroma_stft_max', 'chroma_cqt_min',
       'chroma_cqt_max', 'chroma_cens_min', 'chroma_cens_max',
       'melspectogram_min', 'melspectogram_max', 'mfcc_min', 'mfcc_max',
       'rms_min', 'rms_max', 'spectral_centroid_min', 'spectral_centroid_max',
       'spectral_bandwidth_min', 'spectral_bandwidth_max',
       'spectral_contrast_min', 'spectral_contrast_max',
       'spectral_flatness_min', 'spectral_flatness_max',
       'spectral_rolloff_min', 'spectral_rolloff_max', 'poly_features_min',
       'poly_features_max', 'tonnetz_min', 'tonnetz_max',
       'zero_crossing_rate_min', 'zero_crossing_rate_max', 'tempogram_min',
       'tempogram_max', 'delta_mfcc_min', 'delta_mfcc_max', 'mel_to_stft_min',
       'mel_to_stft_max']
target_var = ['class']
X = data[feature_cols] # Features
y = data[target_var] # Target variable
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif
X_new = SelectKBest(f_classif, k=2).fit_transform(X, y)
X_new.shape
# Out:
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [ 1  3 29 32] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# (1004, 2)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
pima = pd.read_csv("C:/Users/Sahithi Venkatesan/Downloads/Feature-Selection - Sheet1 (12).csv")

# %%
pima.head()
pima.columns.values
# Out:
# array(['spectral_rolloff_min', 'melspectogram_max',
#        'spectral_centroid_max', 'spectral_rolloff_max',
#        'spectral_centroid_min', 'spectral_bandwidth_min',
#        'spectral_bandwidth_max', 'mfcc_min', 'mfcc_max',
#        'spectral_contrast_max', 'delta_mfcc_max', 'delta_mfcc_min',
#        'mel_to_stft_max', 'spectral_contrast_min', 'poly_features_max',
#        'chroma_cens_max', 'class'], dtype=object)

# %%
feature_cols = ['spectral_rolloff_min', 'melspectogram_max',
       'spectral_centroid_max', 'spectral_rolloff_max',
       'spectral_centroid_min', 'spectral_bandwidth_min',
       'spectral_bandwidth_max', 'mfcc_min', 'mfcc_max',
       'spectral_contrast_max', 'delta_mfcc_max', 'delta_mfcc_min',
       'mel_to_stft_max', 'spectral_contrast_min', 'poly_features_max',
       'chroma_cens_max']
target_var = ['class']
X = pima[feature_cols] # Features
y = pima[target_var] # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=2)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
#For decision tree classifer 
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.41721854304635764

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
#Logistic Regression Classifier
from sklearn.preprocessing import StandardScaler


# Create an instance of the scaler and apply it to the data

sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)
from sklearn.linear_model import LogisticRegression
LogReg_clf = LogisticRegression(random_state = 1)

LogReg_clf.fit(X_train, y_train)
y_pred = LogReg_clf.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score


acc =  accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.5165562913907285
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
import matplotlib as plt
from sklearn.neighbors import KNeighborsClassifier
score_list = []
for each in range(1,15):
    knn =  KNeighborsClassifier(n_neighbors= each)
    knn.fit(X_train,y_train)
    score_list.append(knn.score(X_test,y_test))
    

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train,y_train)
prediction = knn.predict(X_test)

print("{}nn score: {}".format(5,knn.score(X_test,y_test)))
# Out:
# <ipython-input-415-0334f6355eb8>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(X_train,y_train)
# <ipython-input-415-0334f6355eb8>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(X_train,y_train)
# <ipython-input-415-0334f6355eb8>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(X_train,y_train)
# <ipython-input-415-0334f6355eb8>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(X_train,y_train)
# ...

# %%
from sklearn.svm import SVC

svm = SVC(random_state = 1)
svm.fit(X_train,y_train)

print("Accuracy of svm algo: ",svm.score(X_test,y_test))
# Out:
# Accuracy of svm algo:  0.5165562913907285
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
#Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)


print("Accuracy of Naive Bayes Algo: ", nb.score(X_test,y_test))
# Out:
# Accuracy of Naive Bayes Algo:  0.5099337748344371
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 50, random_state = 1)
rf.fit(X_train,y_train)

print("Accuracy of Random Forest Algo: ", rf.score(X_test,y_test))
# Out:
# Accuracy of Random Forest Algo:  0.5364238410596026
# <ipython-input-418-8cbfd58079bc>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train,y_train)

# %%
from sklearn.neighbors import (NeighborhoodComponentsAnalysis,
KNeighborsClassifier)
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
nca = NeighborhoodComponentsAnalysis(random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)
nca_pipe = Pipeline([('nca', nca), ('knn', knn)])
nca_pipe.fit(X_train, y_train)
print(nca_pipe.score(X_test, y_test))
# Out:
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 0.47019867549668876
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\pipeline.py:335: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %%
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 0.5

# %%
#Neural Network MLP Classifier
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Sahithi Venkatesan\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.5596026490066225

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-277-692adbe026ec> in <module>
#       3 from sklearn.naive_bayes import MultinomialNB
#       4 clf = MultinomialNB()
# ----> 5 clf.fit(X_train, y_train)
#       6 print(clf.score(X_test,y_test))
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
#     764         self.feature_count_ += safe_sparse_dot(Y.T, X)
# ...
